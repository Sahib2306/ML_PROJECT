# %%
import pandas as pd

# %%
df = pd.read_csv("student_data.csv")

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    StudentID  Age  StudyHours  Attendance  Assignments  MidtermMarks  \
# 0          1   20         1.6          84            9            43
# 1          2   21         3.6          50            7            24
# 2          3   19         3.2          84            1            71
# 3          4   21         4.2          86            1            53
# 4          5   21         1.3          96            9            25
#
#    FinalMarks  ParentalSupport  InternetAccess  Pass
# 0          84                0               1     1
# 1          26                1               0     0
# 2          25                0               1     0
# 3          72                1               0     1
# 4          36                0               0     0

# %%
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StudentID        50 non-null     int64
#  1   Age              50 non-null     int64
#  2   StudyHours       50 non-null     float64
#  3   Attendance       50 non-null     int64
#  4   Assignments      50 non-null     int64
#  5   MidtermMarks     50 non-null     int64
#  6   FinalMarks       50 non-null     int64
#  7   ParentalSupport  50 non-null     int64
#  8   InternetAccess   50 non-null     int64
#  9   Pass             50 non-null     int64
# dtypes: float64(1), int64(9)
# memory usage: 4.0 KB
# None

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#        StudentID        Age  StudyHours  Attendance  Assignments  \
# count   50.00000  50.000000   50.000000   50.000000    50.000000
# mean    25.50000  19.180000    2.814000   74.740000     4.680000
# std     14.57738   1.350586    1.222245   14.228184     2.902778
# min      1.00000  17.000000    0.600000   50.000000     1.000000
# 25%     13.25000  18.000000    1.800000   63.000000     2.000000
# 50%     25.50000  19.000000    3.000000   77.000000     5.000000
# 75%     37.75000  20.000000    3.775000   86.000000     7.000000
# max     50.00000  21.000000    4.800000   98.000000     9.000000
#
#        MidtermMarks  FinalMarks  ParentalSupport  InternetAccess       Pass
# count     50.000000    50.00000        50.000000       50.000000  50.000000
# mean      47.780000    55.68000         0.500000        0.540000   0.520000
# std       17.529322    17.33045         0.505076        0.503457   0.504672
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum)
# Out:
# Missing Values:
# <bound method DataFrame.sum of     StudentID    Age  StudyHours  Attendance  Assignments  MidtermMarks  \
# 0       False  False       False       False        False         False
# 1       False  False       False       False        False         False
# 2       False  False       False       False        False         False
# 3       False  False       False       False        False         False
# 4       False  False       False       False        False         False
# 5       False  False       False       False        False         False
# 6       False  False       False       False        False         False
# 7       False  False       False       False        False         False
# 8       False  False       False       False        False         False
# 9       False  False       False       False        False         False
# 10      False  False       False       False        False         False
# ...

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
print("\nData after preprocessing:")
print(df.head())
# Out:
# Data after preprocessing:
#    StudentID  Age  StudyHours  Attendance  Assignments  MidtermMarks  \
# 0          1   20         1.6          84            9            43
# 1          2   21         3.6          50            7            24
# 2          3   19         3.2          84            1            71
# 3          4   21         4.2          86            1            53
# 4          5   21         1.3          96            9            25
#
#    FinalMarks  ParentalSupport  InternetAccess  Pass
# 0          84                0               1     1
# 1          26                1               0     0
# 2          25                0               1     0
# 3          72                1               0     1
# 4          36                0               0     0

# %%
print("\nPass/Fail Count:")
print(df["Pass"].value_counts())
# Out:
# Pass/Fail Count:
# Pass
# 1    26
# 0    24
# Name: count, dtype: int64

# %%
print("\nCorrelation Matrix:")
print(df.corr())
# Out:
# Correlation Matrix:
#                  StudentID       Age  StudyHours  Attendance  Assignments  \
# StudentID         1.000000 -0.270029    0.037856    0.141443    -0.229089
# Age              -0.270029  1.000000   -0.038647    0.266928     0.165953
# StudyHours        0.037856 -0.038647    1.000000   -0.096720    -0.187958
# Attendance        0.141443  0.266928   -0.096720    1.000000    -0.002056
# Assignments      -0.229089  0.165953   -0.187958   -0.002056     1.000000
# MidtermMarks      0.100990  0.031877   -0.006521    0.273391     0.068375
# FinalMarks        0.227401  0.063545    0.031528    0.121816    -0.092543
# ParentalSupport   0.112259 -0.134629    0.226454   -0.063897    -0.041759
# InternetAccess    0.057005 -0.055825   -0.198262   -0.190826    -0.116744
# Pass              0.185862  0.159288   -0.114608    0.218163     0.129836
#
#                  MidtermMarks  FinalMarks  ParentalSupport  InternetAccess  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["StudyHours"])
plt.title("Study Hours Distribution")
plt.xlabel("Study Hours")
plt.ylabel("Frequency")
plt.show()

# %%
df["TotalMarks"] = df["MidtermMarks"] + df["FinalMarks"]

# %%
df["AverageMarks"] = df["TotalMarks"] / 2

# %%
df["StudyEfficiency"] = df["FinalMarks"] / (df["StudyHours"] + 0.1)

# %%
print("\nData after Feature Engineering:")
print(df.head())
# Out:
# Data after Feature Engineering:
#    StudentID  Age  StudyHours  Attendance  Assignments  MidtermMarks  \
# 0          1   20         1.6          84            9            43
# 1          2   21         3.6          50            7            24
# 2          3   19         3.2          84            1            71
# 3          4   21         4.2          86            1            53
# 4          5   21         1.3          96            9            25
#
#    FinalMarks  ParentalSupport  InternetAccess  Pass  TotalMarks  \
# 0          84                0               1     1         127
# 1          26                1               0     0          50
# 2          25                0               1     0          96
# 3          72                1               0     1         125
# 4          36                0               0     0          61
#
#    AverageMarks  StudyEfficiency
# 0          63.5        49.411765
# 1          25.0         7.027027
# ...

# %%
# %pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop("Pass", axis=1)
y = df["Pass"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)

print("\nModel training completed!")
# Out:
# Model training completed!
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
y_pred = model.predict(X_test)

# %%
print("\nAccuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[6 1]
#  [0 3]]

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.75      1.00      0.86         3
#
#     accuracy                           0.90        10
#    macro avg       0.88      0.93      0.89        10
# weighted avg       0.93      0.90      0.90        10

# %%
df.drop(["StudentID"], axis=1, inplace=True)

print("\nAfter improved preprocessing:")
print(df.head())
# Out:
# After improved preprocessing:
#    Age  StudyHours  Attendance  Assignments  MidtermMarks  FinalMarks  \
# 0   20         1.6          84            9            43          84
# 1   21         3.6          50            7            24          26
# 2   19         3.2          84            1            71          25
# 3   21         4.2          86            1            53          72
# 4   21         1.3          96            9            25          36
#
#    ParentalSupport  InternetAccess  Pass  TotalMarks  AverageMarks  \
# 0                0               1     1         127          63.5
# 1                1               0     0          50          25.0
# 2                0               1     0          96          48.0
# 3                1               0     1         125          62.5
# 4                0               0     0          61          30.5
#
#    StudyEfficiency
# 0        49.411765
# 1         7.027027
# 2         7.575758
# 3        16.744186
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
df["PerformanceScore"] = df["AverageMarks"] * df["StudyHours"]

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()
